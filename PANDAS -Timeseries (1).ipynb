# %% [markdown]
#   **PANDAS TIME SERIES**
#
#   We can find out the data within a certain rannge of date series
#
#
#   -Equivalent to data time python package
#
#   -Used to deal with date time
#
#   -Complex operation on date  time can be done
#
#   TimeStamp
#
#   31-january-2004
#
#   31-01-2004
#
#   31-01-04
#
#   31-01-2004 03:12:11

# %%
data = '15-january-2004'

# %%
type (data)
# Out:
# str

# %%
import pandas as pd

dt = pd.to_datetime(data)
dt
# Out:
# Timestamp('2004-01-15 00:00:00')

# %%
type(dt)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# %d 01,22,23
# Out:
# UsageError: Line magic function `%d` not found.

# %%
# %B january,february,march
# %b jan,feb,mar
# %m -int (month in integer)
# Out:
# UsageError: Line magic function `%B` not found.

# %%
# %y 20,21,22
# %Y 2020,2021,2022
# %H 24hr

# %I 12hr
# %M Minute
# %S Second
# %p AM,PM
# Out:
# UsageError: Line magic function `%y` not found.

# %%
dates =['2020-02-24 2:30:00 PM', 'jan 5,2020 18:45:00' , '01/12/2024' , '2024.01.11' ,'2020/02/12' , '20040131']

import pandas as pd

date_time = pd.to_datetime(dates)

date_time
# Out:
# <ipython-input-14-af0a2974044d>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   date_time = pd.to_datetime(dates)
# DatetimeIndex(['2020-02-24 14:30:00', '2020-01-05 18:45:00',
#                '2024-01-12 00:00:00', '2024-01-11 00:00:00',
#                '2020-02-12 00:00:00', '2004-01-31 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
import pandas as pd

dates = '11-jan-2020'

data_time = pd.to_datetime(dates)

print(date_time)

print(data_time.day)
print(data_time.month)
print(data_time.year)
print(date_time.dayofyear)
print(date_time.is_leap_year)
print(date_time.is_month_end)
print(date_time.month)
print(date_time.quarter)
# Out:
# DatetimeIndex(['2020-02-24 14:30:00', '2020-01-05 18:45:00',
#                '2024-01-12 00:00:00', '2024-01-11 00:00:00',
#                '2020-02-12 00:00:00', '2004-01-31 00:00:00'],
#               dtype='datetime64[ns]', freq=None)
# 11
# 1
# 2020
# Index([55, 5, 12, 11, 43, 31], dtype='int32')
# [ True  True  True  True  True  True]
# [False False False False False  True]
# Index([2, 1, 1, 1, 2, 1], dtype='int32')
# Index([1, 1, 1, 1, 1, 1], dtype='int32')

# %%
import pandas as pd

# %%
df = pd.read_csv('/shirpurGoldRefinery (1) (2).csv')
df
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0    29-December-2017      203.55       206.5     201.00       201.85
# 1    28-December-2017      202.00       207.6     199.55       202.80
# 2    27-December-2017      209.10       213.6     195.20       197.80
# 3    26-December-2017      216.50       219.9     207.20       209.70
# 4    22-December-2017      218.95       233.6     212.40       218.15
# ..                ...         ...         ...        ...          ...
# 243    6-January-2017      110.10       110.1     107.80       110.10
# 244    5-January-2017      101.00       104.9     100.00       104.90
# 245    4-January-2017       99.50       102.0      99.50        99.95
# 246    3-January-2017      102.00       102.0     100.05       100.65
# 247    2-January-2017      104.00       104.0      99.00       101.65
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open
# 0               -1.7
# 1                0.8

# %%
df = pd.read_csv('/shirpurGoldRefinery (1) (2).csv')
df
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0    29-December-2017      203.55       206.5     201.00       201.85
# 1    28-December-2017      202.00       207.6     199.55       202.80
# 2    27-December-2017      209.10       213.6     195.20       197.80
# 3    26-December-2017      216.50       219.9     207.20       209.70
# 4    22-December-2017      218.95       233.6     212.40       218.15
# ..                ...         ...         ...        ...          ...
# 243    6-January-2017      110.10       110.1     107.80       110.10
# 244    5-January-2017      101.00       104.9     100.00       104.90
# 245    4-January-2017       99.50       102.0      99.50        99.95
# 246    3-January-2017      102.00       102.0     100.05       100.65
# 247    2-January-2017      104.00       104.0      99.00       101.65
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open
# 0               -1.7
# 1                0.8

# %%
df.iat[0,0]
# Out:
# '29-December-2017'

# %%
type(df.iat[0,0])
# Out:
# str

# %%
df['TimeStamp']=pd.to_datetime(df['Date'])

df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open  TimeStamp
# 0               -1.7 2017-12-29
# 1                0.8 2017-12-28

# %%
df.iat[0,13]
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
type(df.iat[0,13])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Date']=pd.to_datetime(df['Date'])

df
# Out:
#           Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0   2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1   2017-12-28      202.00       207.6     199.55       202.80  203.118439
# 2   2017-12-27      209.10       213.6     195.20       197.80  202.801825
# 3   2017-12-26      216.50       219.9     207.20       209.70  213.418007
# 4   2017-12-22      218.95       233.6     212.40       218.15  223.089049
# ..         ...         ...         ...        ...          ...         ...
# 243 2017-01-06      110.10       110.1     107.80       110.10  110.048719
# 244 2017-01-05      101.00       104.9     100.00       104.90  103.352347
# 245 2017-01-04       99.50       102.0      99.50        99.95  100.293226
# 246 2017-01-03      102.00       102.0     100.05       100.65  100.784909
# 247 2017-01-02      104.00       104.0      99.00       101.65  101.302024
#
# ...

# %%
df.TimeStamp
# Out:
# 0     2017-12-29
# 1     2017-12-28
# 2     2017-12-27
# 3     2017-12-26
# 4     2017-12-22
#          ...
# 243   2017-01-06
# 244   2017-01-05
# 245   2017-01-04
# 246   2017-01-03
# 247   2017-01-02
# Name: TimeStamp, Length: 248, dtype: datetime64[ns]

# %%
df.TimeStamp.max()
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/shirpurGoldRefinery (1) (2).csv')
df
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0    29-December-2017      203.55       206.5     201.00       201.85
# 1    28-December-2017      202.00       207.6     199.55       202.80
# 2    27-December-2017      209.10       213.6     195.20       197.80
# 3    26-December-2017      216.50       219.9     207.20       209.70
# 4    22-December-2017      218.95       233.6     212.40       218.15
# ..                ...         ...         ...        ...          ...
# 243    6-January-2017      110.10       110.1     107.80       110.10
# 244    5-January-2017      101.00       104.9     100.00       104.90
# 245    4-January-2017       99.50       102.0      99.50        99.95
# 246    3-January-2017      102.00       102.0     100.05       100.65
# 247    2-January-2017      104.00       104.0      99.00       101.65
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df.head()
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
# 2  27-December-2017      209.10       213.6     195.20       197.80
# 3  26-December-2017      216.50       219.9     207.20       209.70
# 4  22-December-2017      218.95       233.6     212.40       218.15
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
# 2  202.801825         24983            426             5066598.0
# 3  213.418007         17782            363             3794999.0
# 4  223.089049        165976           2710            37027428.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%d-%B-%Y')

# %%
df.head(2)
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      65.30             5.50               -1.7
# 1                      58.79             8.05                0.8

# %%
df['day'] = pd.DatetimeIndex(df['Date']).day
df['month'] = pd.DatetimeIndex(df['Date']).month
df['year'] = pd.DatetimeIndex(df['Date']).year

df.head()
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
# 2 2017-12-27      209.10       213.6     195.20       197.80  202.801825
# 3 2017-12-26      216.50       219.9     207.20       209.70  213.418007
# 4 2017-12-22      218.95       233.6     212.40       218.15  223.089049
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
# 2         24983            426             5066598.0                 14168
# 3         17782            363             3794999.0                  7540
# 4        165976           2710            37027428.0                 60121
#
# ...
